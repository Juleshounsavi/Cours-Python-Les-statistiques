# %% [markdown]
# # <div align="center">REALISATION D'UN TEST STATISTIQUE D'ESTIMATION DE LA MOYENNE AVEC SCIPY</div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp as ttest1

# %%
data=pd.read_csv("ecoles-creches-idf.csv")
data.head()
# Out:
#          ID                                                nom  departement  \
# 0  0750026W  L'Enseignement par petits groupes (Ecole secon...           75
# 1  0750106H  Ecole technologique privée CCIP Centre des For...           75
# 2  0750132L        Ecole primaire privée Notre-Dame-Saint Roch           75
# 3  0750136R                Ecole primaire privée Saint-Sauveur           75
# 4  0750138T   Ecole primaire privée Sainte Geneviève du Marais           75
#
#       ville     CP        type   NO2_2012   NO2_2013   NO2_2014   NO2_2015  \
# 0  Paris 15  75015  secondaire  41.316912  42.916257  40.610102  37.182711
# 1  Paris 20  75020  secondaire  63.683878  60.890328  53.322156  45.804898
# 2  Paris 01  75001    primaire  41.507336  41.598420  42.855147  39.286859
# 3  Paris 02  75002    primaire  45.197342  44.280198  45.187931  40.855468
# 4  Paris 03  75003    primaire  40.109546  39.257252  39.688121  37.249166
#
# ...

# %%
data.shape
# Out:
# (12530, 25)

# %% [markdown]
# # PROCEDURE DE L'ANALYSE

# %% [markdown]
# ### -Stocker les données d'emissions de NO2 de 2012 à 2016 dans une dataframe df1.
# ### -Stocker les données d'emissions de NO2 en 2017 dans une dataframe df2.
# ### -Calculer les moyennes **m1** et **m2** des deux echantillons.
# ### -Mise en place des hypotheses:
#     -H0: il n'y a pas de difference entre les deux moyennes.
#     -H1: il y a une difference significative entre les deux moyennes.
# ### -Faire le test ttest1de scipy.stats ttest_1samp en inserant df2.val et m1 et lire la valeur de statistic et pvalue.
# ####       -Si p_value<0.05 ==>On peut rejetter H0.
# ####       -Si P_value>0.05 ==>On peut maintenir H0.
